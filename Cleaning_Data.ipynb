# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('survey_results_public.csv')
df.head(10)
# Out:
# C:\Users\Dell\AppData\Local\Temp\ipykernel_16568\2638868445.py:1: DtypeWarning: Columns (0: JobSatPoints_15_TEXT, 1: DatabaseHaveEntry, 2: DevEnvHaveEntry, 3: SOTagsHaveEntry, 4: SOTagsWant Entry, 5: OfficeStackWantEntry, 6: CommPlatformHaveEntr, 7: CommPlatformWantEntr, 8: SO_Actions_15_TEXT, 9: AIAgentOrchestration, 10: AIAgentObsWrite) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv('survey_results_public.csv')
#    ResponseId                      MainBranch              Age  \
# 0           1  I am a developer by profession  25-34 years old
# 1           2  I am a developer by profession  25-34 years old
# 2           3  I am a developer by profession  35-44 years old
# 3           4  I am a developer by profession  35-44 years old
# 4           5  I am a developer by profession  35-44 years old
# 5           6  I am a developer by profession  45-54 years old
# 6           7  I am a developer by profession  25-34 years old
# ...

# %%
# Removes rows where all values in the 'AIAgentOrchWrite' column are NaN
df.dropna(axis=0, how='all', subset=['AIAgentOrchWrite','AIAgentOrchestration'])
# Out:
#        ResponseId                      MainBranch              Age  \
# 0               1  I am a developer by profession  25-34 years old
# 10             11  I am a developer by profession  25-34 years old
# 15             16  I am a developer by profession  18-24 years old
# 28             29  I am a developer by profession  35-44 years old
# 42             43  I am a developer by profession  35-44 years old
# ...           ...                             ...              ...
# 48990       48991  I am a developer by profession  25-34 years old
# 49006       49007  I am a developer by profession  35-44 years old
# 49089       49090           I am learning to code  18-24 years old
# 49098       49099  I am a developer by profession  45-54 years old
# 49175       49176  I am a developer by profession  25-34 years old
#
#                                                  EdLevel  \
# 0        Master’s degree (M.A., M.S., M.Eng., MBA, etc.)
# ...

# %%
df.isna()
# Out:
#        ResponseId  MainBranch    Age  EdLevel  Employment  EmploymentAddl  \
# 0           False       False  False    False       False           False
# 1           False       False  False    False       False            True
# 2           False       False  False    False       False           False
# 3           False       False  False    False       False           False
# 4           False       False  False    False       False           False
# ...           ...         ...    ...      ...         ...             ...
# 49186       False       False  False    False       False            True
# 49187       False       False  False    False       False           False
# 49188       False       False  False    False       False           False
# 49189       False       False  False    False       False           False
# 49190       False       False  False    False       False           False
#
#        WorkExp  LearnCodeChoose  LearnCode  LearnCodeAI  ...  \
# ...

# %%
df.fillna('MISSING')
# Out:
#        ResponseId                                         MainBranch  \
# 0               1                     I am a developer by profession
# 1               2                     I am a developer by profession
# 2               3                     I am a developer by profession
# 3               4                     I am a developer by profession
# 4               5                     I am a developer by profession
# ...           ...                                                ...
# 49186       49187                        I code primarily as a hobby
# 49187       49188                     I am a developer by profession
# 49188       49189                     I am a developer by profession
# 49189       49190                     I am a developer by profession
# 49190       49191  I am not primarily a developer, but I write co...
#
#                    Age                                            EdLevel  \
# ...

# %%
df.dtypes
# Out:
# ResponseId               int64
# MainBranch                 str
# Age                        str
# EdLevel                    str
# Employment                 str
#                         ...
# AIAgentExtWrite            str
# AIHuman                    str
# AIOpen                     str
# ConvertedCompYearly    float64
# JobSat                 float64
# Length: 172, dtype: object

# %%
df['WorkExp']=df['WorkExp'].astype(int)
# Out:
# ---------------------------------------------------------------------------
# IntCastingNaNError                        Traceback (most recent call last)
# Cell In[15], line 1
# ----> 1 df['WorkExp']=df['WorkExp'].astype(int)
#
# File d:\ipynb\langgraph\Lib\site-packages\pandas\core\generic.py:6541, in NDFrame.astype(self, dtype, copy, errors)
#    6537     results = [ser.astype(dtype, errors=errors) for _, ser in self.items()]
#    6539 else:
#    6540     # else, only a single dtype is given
# -> 6541     new_data = self._mgr.astype(dtype=dtype, errors=errors)
#    6542     res = self._constructor_from_mgr(new_data, axes=new_data.axes)
#    6543     return res.__finalize__(self, method="astype")
#
# File d:\ipynb\langgraph\Lib\site-packages\pandas\core\internals\managers.py:611, in BaseBlockManager.astype(self, dtype, errors)
#     610 def astype(self, dtype, errors: str = "raise") -> Self:
# --> 611     return self.apply("astype", dtype=dtype, errors=errors)
#
# ...

# %%
df['WorkExp']=df['WorkExp'].astype(float)
df['WorkExp'].mean()
# Out:
# np.float64(13.367402606485907)

# %%
df['WorkExp'].median()
# Out:
# np.float64(10.0)
